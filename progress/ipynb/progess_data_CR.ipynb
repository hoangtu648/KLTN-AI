# %%
import pandas as pd
from langdetect import detect
from deep_translator import GoogleTranslator
import re
import spacy
from underthesea import word_tokenize, pos_tag
from nltk.corpus import stopwords
import numpy as np
from collections import defaultdict
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns

# %%
nlp = spacy.load('en_core_web_md')
stop_words = set(stopwords.words('english'))

# %%
csv_cr = "../../data/raw/UpdatedResumeDataSet.csv"
csv_jd_clean = "../../data/clean/clean_jobs_v2.csv"

# %%
df_cr = pd.read_csv(csv_cr)
df_jd = pd.read_csv(csv_jd_clean)

# %%
df_cr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 962 entries, 0 to 961
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  962 non-null    object
#  1   Resume    962 non-null    object
# dtypes: object(2)
# memory usage: 15.2+ KB

# %%
df_jd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2081 entries, 0 to 2080
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2081 non-null   object
#  1   title                  2081 non-null   object
#  2   company                2081 non-null   object
#  3   location               2081 non-null   object
#  4   salary                 2081 non-null   object
#  5   work_type              841 non-null    object
#  6   description            2081 non-null   object
#  7   requirements           2081 non-null   object
#  8   skills                 841 non-null    object
#  9   category               1305 non-null   object
#  10  language               2081 non-null   object
#  11  description_clean      2081 non-null   object
#  12  requirements_clean     2081 non-null   object
#  13  description_en_clean   2081 non-null   object
#  14  requirements_en_clean  2081 non-null   object
#  15  primary_skills         2081 non-null   object
#  16  secondary_skills       2081 non-null   object
#  17  adjectives             2081 non-null   object
#  18  adverbs                2081 non-null   object
# dtypes: object(19)
# memory usage: 309.0+ KB

# %%
df_jd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2081 entries, 0 to 2080
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2081 non-null   object
#  1   title                  2081 non-null   object
#  2   company                2081 non-null   object
#  3   location               2081 non-null   object
#  4   salary                 2081 non-null   object
#  5   work_type              841 non-null    object
#  6   description            2081 non-null   object
#  7   requirements           2081 non-null   object
#  8   skills                 841 non-null    object
#  9   category               1305 non-null   object
#  10  language               2081 non-null   object
#  11  description_clean      2081 non-null   object
#  12  requirements_clean     2081 non-null   object
#  13  description_en_clean   2081 non-null   object
#  14  requirements_en_clean  2081 non-null   object
#  15  primary_skills         2081 non-null   object
#  16  secondary_skills       2081 non-null   object
#  17  adjectives             2081 non-null   object
#  18  adverbs                2081 non-null   object
# dtypes: object(19)
# memory usage: 309.0+ KB

# %%
df_cr['Category'].unique()
# Out:
# array(['Data Science', 'HR', 'Advocate', 'Arts', 'Web Designing',
#        'Mechanical Engineer', 'Sales', 'Health and fitness',
#        'Civil Engineer', 'Java Developer', 'Business Analyst',
#        'SAP Developer', 'Automation Testing', 'Electrical Engineering',
#        'Operations Manager', 'Python Developer', 'DevOps Engineer',
#        'Network Security Engineer', 'PMO', 'Database', 'Hadoop',
#        'ETL Developer', 'DotNet Developer', 'Blockchain', 'Testing'],
#       dtype=object)

# %%
list_job_to_remove = ['Sales','Health and fitness','PMO','Arts']

df_cr = df_cr[~df_cr['Category'].isin(list_job_to_remove)]

# %%
df_cr['Category'].unique()
# Out:
# array(['Data Science', 'HR', 'Advocate', 'Web Designing',
#        'Mechanical Engineer', 'Civil Engineer', 'Java Developer',
#        'Business Analyst', 'SAP Developer', 'Automation Testing',
#        'Electrical Engineering', 'Operations Manager', 'Python Developer',
#        'DevOps Engineer', 'Network Security Engineer', 'Database',
#        'Hadoop', 'ETL Developer', 'DotNet Developer', 'Blockchain',
#        'Testing'], dtype=object)

# %%
df_jd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2081 entries, 0 to 2080
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2081 non-null   object
#  1   title                  2081 non-null   object
#  2   company                2081 non-null   object
#  3   location               2081 non-null   object
#  4   salary                 2081 non-null   object
#  5   work_type              841 non-null    object
#  6   description            2081 non-null   object
#  7   requirements           2081 non-null   object
#  8   skills                 841 non-null    object
#  9   category               1305 non-null   object
#  10  language               2081 non-null   object
#  11  description_clean      2081 non-null   object
#  12  requirements_clean     2081 non-null   object
#  13  description_en_clean   2081 non-null   object
#  14  requirements_en_clean  2081 non-null   object
#  15  primary_skills         2081 non-null   object
#  16  secondary_skills       2081 non-null   object
#  17  adjectives             2081 non-null   object
#  18  adverbs                2081 non-null   object
# dtypes: object(19)
# memory usage: 309.0+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Loại bỏ các dòng có giá trị None/NaN trong cột 'category'
df_filtered = df_cr.dropna(subset=['Category'])

# Tính toán tần suất chỉ trên các dòng có giá trị hợp lệ
freq = df_filtered['Category'].value_counts().rename_axis('Category').reset_index(name='Count')


# Tạo biểu đồ cột
plt.figure(figsize=(12, 6))
plt.bar(freq['Category'], freq['Count'])
plt.xticks(rotation=45, ha='right')
plt.ylabel('Count')
plt.title('Frequency of Each Category (Excluding None/NaN values)')
plt.tight_layout()
plt.show()

# %%
columns_drop = ['work_type','language','company','location','salary','description','requirements']
df_jd.drop(columns_drop, axis=1, inplace=True)

# %%
import ast
df_jd['primary_skills'] = df_jd['primary_skills'].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) else x
)
df_jd = df_jd.dropna(subset=['primary_skills'])
mask = df_jd['primary_skills'].apply(
    lambda x: isinstance(x, (list, tuple, set)) and len(x) > 0
)
df_jd = df_jd[mask].reset_index(drop=True)

# %%
def read_skills(file_path):
    skills = []
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if line and not line.startswith('#'):
                skills.append(line.lower())
    return skills
skills_list = read_skills('../../data/skills.txt')

# %%
import re
from collections import Counter
import spacy

adj_counter = Counter()
adv_counter = Counter()

def clean_text_for_matching(text):
    if not isinstance(text, str) or not text.strip():
        return ""
    
    protected = []
    def _protect(match):
        protected.append(match.group(0))
        return f"__PROT_{len(protected)-1}__"
    
    # Bảo vệ các thuật ngữ IT như C#, C++, node.js trước mọi xử lý
    text = re.sub(r"\b\w+[#+.]\w*\b", _protect, text, flags=re.IGNORECASE)
    
    # Các bước xử lý văn bản
    text = text.lower()
    text = re.sub(r"(?<=\b\w)[-/](?=\w\b)", " ", text)
    text = re.sub(r"\s*&\s*", " ", text)
    text = re.sub(r"http\S+|@\s|\s@(?=\s)|\s#", " ", text)
    text = re.sub(r"[()]", " ", text)
    text = re.sub(r"(?<!\w)[.,!?;:–—](?!\w)", " ", text)
    text = re.sub(r"[\n\r\t]", " ", text)
    text = re.sub(r"\b\w*['’‘]\w*\b", "", text)
    text = re.sub(r"\s*[-–—]{2,}\s*", " ", text)
    text = re.sub(r"[“”‘’«»„‟]", " ", text)
    text = re.sub(r"(?<=\w)[.,!:](?=\s|$)", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    text = re.sub(r"/", " ", text)
    text = re.sub(r"(?<=\w):(?=\w)", " ", text)
    text = re.sub(r"([^a-zA-Z0-9\s])\1{2,}", "", text)
    
    
    # Khôi phục các thuật ngữ được bảo vệ
    for i, word in enumerate(protected):
        text = text.replace(f"__prot_{i}__", word.lower())
    
    return text

def nomalize_skills(skills):
    return [clean_text_for_matching(skill).strip() for skill in skills]


def generate_ngrams(text, max_n=3):
    tokens = text.split()
    ngrams = []
    for n in range(1, max_n+1):
        ngrams.extend([' '.join(tokens[i:i+n]) for i in range(len(tokens)-n+1)])
    return ngrams

def extract_skills(text):
    if not isinstance(text.lower(), str) or pd.isna(text.lower()):
        return []

    ngrams = generate_ngrams(text.lower(), max_n=3)

    found = [skill for skill in skills_list if skill in ngrams]

    return list(dict.fromkeys(found))



def extract_adjectives(text):
    if not isinstance(text, str) or pd.isna(text):
        return []

    doc = nlp(text)
    adjs = [
        token.lemma_.lower()
        for token in doc
        if token.pos_ == "ADJ"
        and len(token.lemma_) > 2            # loại từ ngắn như "as", "own"
        and token.is_alpha                   # bỏ từ chứa số, ký hiệu
        and not token.is_stop                # loại stop words mặc định của spaCy
    ]
    adj_counter.update(adjs)
    return list(set(adjs))

def extract_adverbs(text):
    if not isinstance(text, str) or pd.isna(text):
        return []

    doc = nlp(text)
    advs = [
        token.lemma_.lower()
        for token in doc
        if token.pos_ == "ADV"
        and len(token.lemma_) > 2
        and token.is_alpha
        and not token.is_stop
    ]
    adv_counter.update(advs)
    return list(set(advs))

# %%
df_cr['resume_cleaned'] = df_cr['Resume'].apply(clean_text_for_matching)

# %%
df_cr['skills'] = df_cr['resume_cleaned'].apply(extract_skills)

# %%
for i in range(len(df_cr)):
    df_cr.at[i, 'id'] = "CANDIDATE_" + str(i)

# %%
df_cr = df_cr.dropna()

# %%
pd.DataFrame(df_cr)
# Out:
#              Category                                             Resume  \
# 0        Data Science  Skills * Programming Languages: Python (pandas...
# 1        Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2        Data Science  Areas of Interest Deep Learning, Control Syste...
# 3        Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4        Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
# ..                ...                                                ...
# 821     ETL Developer  Education Details \r\nJanuary 2015 Bachelor of...
# 822     ETL Developer  SKILL SET â Talend Big Data â Informatica ...
# 823     ETL Developer  Computer skills: - Yes. SQL knowledge-yes Unix...
# 824  DotNet Developer  TECHNICAL SKILLS â¢ Web Technologies: ASP .NE...
# 825  DotNet Developer  Participated in intra college cricket competit...
#
#                                         resume_cleaned  \
# 0    skills * programming languages python pandas n...
# 1    education details may 2013 to may 2017 b.e uit...
# 2    areas of interest deep learning control system...
# 3    skills â¢ r â¢ python â¢ sap hana â¢ table...
# 4    education details mca ymcaust faridabad haryan...
# ..                                                 ...
# 821  education details january 2015 bachelor of eng...
# 822  skill set â talend big data â informatica ...
# 823  computer skills - yes sql knowledge-yes unix k...
# 824  technical skills â¢ web technologies asp .net...
# 825  participated in intra college cricket competit...
#
#                                                 skills             id
# 0    [python, java, javascript, angular, flask, jqu...    CANDIDATE_0
# 1         [machine learning, data scientist, platform]    CANDIDATE_1
# 2    [python, java, matlab, flask, deep learning, j...    CANDIDATE_2
# 3    [python, c#, swift, sql, sql server, lstm, k-m...    CANDIDATE_3
# 4                                           [database]    CANDIDATE_4
# ..                                                 ...            ...
# 821  [sql, oracle, automation, unit test, performan...  CANDIDATE_821
# 822  [sql, mysql, sql server, aws, data warehouse, ...  CANDIDATE_822
# 823    [sql, data warehouse, etl developer, etl, unix]  CANDIDATE_823
# 824  [c++, c#, jquery, sql, sql server, html, css, ...  CANDIDATE_824
# 825                       [sql, sql server, html, css]  CANDIDATE_825
#
# [690 rows x 5 columns]

# %%
print(df_cr['skills'][0])
print(df_jd['primary_skills'][1])
print(list(set(['python','javascript','html','css']) - set(['python','java'])))
# Out:
# ['python', 'java', 'javascript', 'angular', 'flask', 'jquery', 'sql', 'mysql', 'cassandra', 'elasticsearch', 'scikit-learn', 'pandas', 'numpy', 'chatbot', 'computer vision', 'natural language processing', 'machine learning', 'html', 'css', 'random forest', 'kafka', 'tableau', 'plotly', 'matplotlib', 'cloud', 'security', 'knn', 'qa', 'platform', 'database', 'systems', 'pipeline', 'analytics', 'git', 'docker', 'logstash', 'kibana', 'monitoring']
# ['python', 'bash', 'aws', 'ci cd', 'devops', 'devops engineer', 'infrastructure', 'systems', 'git', 'gitlab', 'git flow', 'docker', 'jenkins', 'teamcity', 'codepipeline', 'codedeploy', 'terraform', 'ansible', 'puppet', 'chef', 'cloudformation', 'linux', 'agile']
# ['css', 'html', 'javascript']

# %%
pd.DataFrame(df_jd)
# Out:
#             id                                            title  \
# 0        JOB_0                                   MLops Engineer
# 1        JOB_1              Senior DevOps Engineer (Cloud, AWS)
# 2        JOB_2  VTS - Chuyên Viên Quản Trị Dự Án (Agile/ Azure)
# 3        JOB_4    VHT - Embedded Software Engineer (Linux, C++)
# 4        JOB_5                  Quality Assurance Manager (QAM)
# ...        ...                                              ...
# 1725  JOB_2505      Nhân Viên Thiết Kế Đồ Họa/ Graphic Designer
# 1726  JOB_2506                        Graphic & Motion Designer
# 1727  JOB_2507                          Chuyên Graphic Designer
# 1728  JOB_2510                        Nhân Viên Thiết Kế Đồ Họa
# 1729  JOB_2512                                    IOS Developer
#
#                                                  skills  \
# 0     MLOps, Python, Linux, Docker, Data Science, Te...
# 1     AWS, DevOps, Cloud, Cloud-native Architecture,...
# 2     Project Management, Business Analysis, Presale...
# 3     Embedded, C++, Linux, C language, Embedded Eng...
# 4     PQA, Team Management, QA QC, ISO 27001, IT Aud...
# ...                                                 ...
# 1725                                                NaN
# 1726                                                NaN
# 1727                                                NaN
# 1728                                                NaN
# 1729                                                NaN
#
#                      category  \
# 0                         NaN
# 1     DevOps / MLOps / SysOps
# 2                         NaN
# 3              Embedded / IoT
# 4                         NaN
# ...                       ...
# 1725   UI‑UX / Graphic Design
# 1726   UI‑UX / Graphic Design
# 1727   UI‑UX / Graphic Design
# 1728   UI‑UX / Graphic Design
# 1729         Mobile Developer
#
#                                       description_clean  \
# 0     we are looking for qualified mlops engineer fo...
# 1     we are seeking an experienced senior devops en...
# 2     ecotek đang dẫn dắt ecopark phát triển trở thà...
# 3     với hơn 1200 nhân sự chất lượng cao tổng công ...
# 4     xây dựng khung quy trình công ty và chủ trì cả...
# ...                                                 ...
# 1725  mô tả công việc thiết kế key visuals cho các c...
# 1726  mô tả công việc - thiết kế các graphic thumbna...
# 1727  mô tả công việc - thiết kế ấn phẩm truyền thôn...
# 1728  mô tả công việc thiết kế key visuals cho các c...
# 1729  mô tả công việc tham gia phát triển các ứng dụ...
#
#                                      requirements_clean  \
# 0     bs or ms in computer science or related fields...
# 1     requirements or degree in computer science inf...
# 2     tư duy logic tốt tư duy hướng giải pháp tư duy...
# 3     tốt nghiệp đại học chính quy loại khá trở lên ...
# 4     tốt nghiệp đại học về các lĩnh vực công nghệ t...
# ...                                                 ...
# 1725  khả năng làm việc độc lập và nhóm khả năng sán...
# 1726  adobe photoshop adobe illustrator adobe after ...
# 1727  sử dụng thành thạo photoshop sử dụng thành thạ...
# 1728  khả năng làm việc độc lập và nhóm khả năng sán...
# 1729  xcode kiểm thử và gỡ lỗi ứng dụng swift hoặc o...
#
#                                    description_en_clean  \
# 0     we are looking for qualified mlops engineer fo...
# 1     we are seeking an experienced senior devops en...
# 2     Ecotek is leading Ecopark to become a smart ci...
# 3     With more than 1200 high quality personnel Vie...
# 4     Develop a company process framework and assume...
# ...                                                 ...
# 1725  Key Visuals design description for online camp...
# 1726  Job description- Designing graphic thumbnail b...
# 1727  Job description - Designing Banner Poster Comm...
# 1728  Key Visuals design description for online camp...
# 1729  Job description participating in the developme...
#
#                                   requirements_en_clean  \
# 0     bs or ms in computer science or related fields...
# 1     requirements or degree in computer science inf...
# 2     Good logical thinking of thinking solutions to...
# 3     Graduated with a regular university or higher,...
# 4     Graduated from university in the field of elec...
# ...                                                 ...
# 1725  The ability to work independently and the crea...
# 1726  Adobe Photoshop Adobe Illustrator Adobe After ...
# 1727  Proficient use of Photoshop is proficient in u...
# 1728  The ability to work independently and the crea...
# 1729  Xcode test and debugging Swift or Objective ap...
#
#                                          primary_skills  \
# 0     [python, java, javascript, c++, tensorflow, py...
# 1     [python, bash, aws, ci cd, devops, devops engi...
# 2                                     [software, sales]
# 3                                               [linux]
# 4     [cicd, power bi, software, qa, production, svn...
# ...                                                 ...
# 1725                 [software, illustrator, photoshop]
# 1726  [illustrator, photoshop, adobe photoshop, adob...
# 1727                           [illustrator, photoshop]
# 1728     [software, typography, illustrator, photoshop]
# 1729           [swift, ui ux, ios, xcode, ui ux design]
#
#                                        secondary_skills  \
# 0     ['computer vision', 'backend', 'mobile', 'data...
# 1     ['automation', 'aws', 'software', 'devops', 'd...
# 2            ['software', 'network', 'project manager']
# 3     ['mobile', 'network', 'security', 'embedded', ...
# 4     ['cicd', 'power bi', 'software', 'qa', 'produc...
# ...                                                 ...
# 1725  ['designer', 'sales', 'illustrator', 'photoshop']
# 1726                       ['illustrator', 'photoshop']
# 1727                                       ['designer']
# 1728                                          ['sales']
# 1729  ['ui ux', 'oop', 'software', 'backend', 'ci cd...
#
#                                              adjectives  \
# 0     ['qualified', 'familiar', 'digital', 'primary'...
# 1     ['agile', 'professional', 'rapid', 'experience...
# 2     ['digital', 'important', 'smart', 'urban', 'lo...
# 3     ['optical', 'high', 'core', 'military', 'vietn...
# 4     ['agile', 'internal', 'multiple', 'commercial'...
# ...                                                 ...
# 1725  ['offline', 'short', 'practical', 'online', 'g...
# 1726  ['high', 'official', 'annual', 'equivalent', '...
# 1727  ['artistic', 'relevant', 'dynamic', 'right', '...
# 1728  ['offline', 'practical', 'lunchompany', 'dynam...
# 1729  ['knowledgeable', 'high', 'practical', 'object...
#
#                                                 adverbs
# 0                                                    []
# 1     ['occasionally', 'quickly', 'independently', '...
# 2                  ['currently', 'clearly', 'directly']
# 3                                                    []
# 4                   ['internationally', 'proficiently']
# ...                                                 ...
# 1725              ['right', 'closely', 'independently']
# 1726                                ['right', 'online']
# 1727                ['right', 'online', 'proficiently']
# 1728  ['right', 'online', 'closely', 'independently'...
# 1729                ['right', 'online', 'successfully']
#
# [1730 rows x 12 columns]

# %%
def norm_set(lst):
    """Trả về set lowercase bỏ khoảng trắng của 1 list kỹ năng."""
    return {s.strip().lower() for s in lst if s}

# %%
df_cr['cr_skill_set'] = df_cr['skills'].apply(norm_set)
df_cr['adjectives_cr'] = df_cr['resume_cleaned'].apply(extract_adjectives)
df_cr['adverbs_cr']    = df_cr['resume_cleaned'].apply(extract_adverbs)
df_cr['adj_weight_cr'] = df_cr['adjectives_cr'].apply(len)

# %%
df_jd['jd_skill_set']  = df_jd['primary_skills'].apply(norm_set)

# %%
rows = []
for cr in df_cr.itertuples(index=False):
    for jd in df_jd.itertuples(index=False):
        primary   = list(cr.cr_skill_set & jd.jd_skill_set)
        secondary = list(cr.cr_skill_set - jd.jd_skill_set)

        rows.append(
            {
                "cr_id"              : cr.id,
                "jd_id"              : jd.id,
                "cr_category"        : cr.Category,
                "jd_name"            : jd.title,
                "primary_skills_jd"  : jd.primary_skills,
                "secondary_skills_jd": jd.secondary_skills,
                "adjectives_jd"      : jd.adjectives,
                "adverbs_jd"         : jd.adverbs,
                "primary_skills_cr"  : primary,
                "secondary_skills_cr": secondary,
                "adjectives_cr"      : cr.adjectives_cr,
                "adverbs_cr"         : cr.adverbs_cr,
                "adjectives_weight_cr": cr.adj_weight_cr,
            }
        )
df_pairs = pd.DataFrame(rows)

# %%
pd.DataFrame(df_pairs)
# Out:
#                  cr_id     jd_id       cr_category  \
# 0          CANDIDATE_0     JOB_0      Data Science
# 1          CANDIDATE_0     JOB_1      Data Science
# 2          CANDIDATE_0     JOB_2      Data Science
# 3          CANDIDATE_0     JOB_4      Data Science
# 4          CANDIDATE_0     JOB_5      Data Science
# ...                ...       ...               ...
# 1193695  CANDIDATE_825  JOB_2505  DotNet Developer
# 1193696  CANDIDATE_825  JOB_2506  DotNet Developer
# 1193697  CANDIDATE_825  JOB_2507  DotNet Developer
# 1193698  CANDIDATE_825  JOB_2510  DotNet Developer
# 1193699  CANDIDATE_825  JOB_2512  DotNet Developer
#
#                                                  jd_name  \
# 0                                         MLops Engineer
# 1                    Senior DevOps Engineer (Cloud, AWS)
# 2        VTS - Chuyên Viên Quản Trị Dự Án (Agile/ Azure)
# 3          VHT - Embedded Software Engineer (Linux, C++)
# 4                        Quality Assurance Manager (QAM)
# ...                                                  ...
# 1193695      Nhân Viên Thiết Kế Đồ Họa/ Graphic Designer
# 1193696                        Graphic & Motion Designer
# 1193697                          Chuyên Graphic Designer
# 1193698                        Nhân Viên Thiết Kế Đồ Họa
# 1193699                                    IOS Developer
#
#                                          primary_skills_jd  \
# 0        [python, java, javascript, c++, tensorflow, py...
# 1        [python, bash, aws, ci cd, devops, devops engi...
# 2                                        [software, sales]
# 3                                                  [linux]
# 4        [cicd, power bi, software, qa, production, svn...
# ...                                                    ...
# 1193695                 [software, illustrator, photoshop]
# 1193696  [illustrator, photoshop, adobe photoshop, adob...
# 1193697                           [illustrator, photoshop]
# 1193698     [software, typography, illustrator, photoshop]
# 1193699           [swift, ui ux, ios, xcode, ui ux design]
#
#                                        secondary_skills_jd  \
# 0        ['computer vision', 'backend', 'mobile', 'data...
# 1        ['automation', 'aws', 'software', 'devops', 'd...
# 2               ['software', 'network', 'project manager']
# 3        ['mobile', 'network', 'security', 'embedded', ...
# 4        ['cicd', 'power bi', 'software', 'qa', 'produc...
# ...                                                    ...
# 1193695  ['designer', 'sales', 'illustrator', 'photoshop']
# 1193696                       ['illustrator', 'photoshop']
# 1193697                                       ['designer']
# 1193698                                          ['sales']
# 1193699  ['ui ux', 'oop', 'software', 'backend', 'ci cd...
#
#                                              adjectives_jd  \
# 0        ['qualified', 'familiar', 'digital', 'primary'...
# 1        ['agile', 'professional', 'rapid', 'experience...
# 2        ['digital', 'important', 'smart', 'urban', 'lo...
# 3        ['optical', 'high', 'core', 'military', 'vietn...
# 4        ['agile', 'internal', 'multiple', 'commercial'...
# ...                                                    ...
# 1193695  ['offline', 'short', 'practical', 'online', 'g...
# 1193696  ['high', 'official', 'annual', 'equivalent', '...
# 1193697  ['artistic', 'relevant', 'dynamic', 'right', '...
# 1193698  ['offline', 'practical', 'lunchompany', 'dynam...
# 1193699  ['knowledgeable', 'high', 'practical', 'object...
#
#                                                 adverbs_jd  \
# 0                                                       []
# 1        ['occasionally', 'quickly', 'independently', '...
# 2                     ['currently', 'clearly', 'directly']
# 3                                                       []
# 4                      ['internationally', 'proficiently']
# ...                                                    ...
# 1193695              ['right', 'closely', 'independently']
# 1193696                                ['right', 'online']
# 1193697                ['right', 'online', 'proficiently']
# 1193698  ['right', 'online', 'closely', 'independently'...
# 1193699                ['right', 'online', 'successfully']
#
#                                          primary_skills_cr  \
# 0        [python, git, javascript, docker, java, machin...
# 1                           [git, systems, docker, python]
# 2                                                       []
# 3                                                       []
# 4                                                     [qa]
# ...                                                    ...
# 1193695                                                 []
# 1193696                                                 []
# 1193697                                                 []
# 1193698                                                 []
# 1193699                                                 []
#
#                                        secondary_skills_cr  \
# 0        [plotly, pipeline, random forest, monitoring, ...
# 1        [plotly, pipeline, random forest, monitoring, ...
# 2        [plotly, python, pipeline, random forest, moni...
# 3        [plotly, python, pipeline, random forest, moni...
# 4        [plotly, python, pipeline, random forest, moni...
# ...                                                    ...
# 1193695                       [sql server, sql, html, css]
# 1193696                       [sql server, sql, html, css]
# 1193697                       [sql server, sql, html, css]
# 1193698                       [sql server, sql, html, css]
# 1193699                       [sql server, sql, html, css]
#
#                                              adjectives_cr  \
# 0        [redundant, negative, neural, past, social, an...
# 1        [redundant, negative, neural, past, social, an...
# 2        [redundant, negative, neural, past, social, an...
# 3        [redundant, negative, neural, past, social, an...
# 4        [redundant, negative, neural, past, social, an...
# ...                                                    ...
# 1193695              [intra, english, semi, net, cultural]
# 1193696              [intra, english, semi, net, cultural]
# 1193697              [intra, english, semi, net, cultural]
# 1193698              [intra, english, semi, net, cultural]
# 1193699              [intra, english, semi, net, cultural]
#
#                                      adverbs_cr  adjectives_weight_cr
# 0        [plotly, personally, well, frequently]                    37
# 1        [plotly, personally, well, frequently]                    37
# 2        [plotly, personally, well, frequently]                    37
# 3        [plotly, personally, well, frequently]                    37
# 4        [plotly, personally, well, frequently]                    37
# ...                                         ...                   ...
# 1193695                                      []                     5
# 1193696                                      []                     5
# 1193697                                      []                     5
# 1193698                                      []                     5
# 1193699                                      []                     5
#
# [1193700 rows x 13 columns]

# %%
skills_series = df_pairs['primary_skills_cr'].explode().dropna().str.strip()

# Đếm kỹ năng phổ biến nhất
skill_counts = Counter(skills_series)
top_skills = skill_counts.most_common(20)

# Chuyển thành DataFrame để vẽ biểu đồ
skills_df = pd.DataFrame(top_skills, columns=['Skill', 'Count'])

# Vẽ biểu đồ
plt.figure(figsize=(12, 8))
sns.barplot(x='Count', y='Skill', data=skills_df, palette='viridis')
plt.title('Top 20 Kỹ năng được yêu cầu nhiều nhất')
plt.xlabel('Số lượng công việc yêu cầu')
plt.ylabel('Kỹ năng')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21016\2440652468.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='Skill', data=skills_df, palette='viridis')

# %%
df_pairs.dropna(inplace=True)
df_pairs.to_csv('../../data/clean/clean_resumes_v2.csv', index=False, encoding='utf-8')

# %% [markdown]
# ===========================================

# %%
df_pairs = pd.read_csv('../../data/clean/clean_resumes_v2.csv')

df_pairs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1193700 entries, 0 to 1193699
# Data columns (total 13 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   cr_id                 1193700 non-null  object
#  1   jd_id                 1193700 non-null  object
#  2   cr_category           1193700 non-null  object
#  3   jd_name               1193700 non-null  object
#  4   primary_skills_jd     1193700 non-null  object
#  5   secondary_skills_jd   1193700 non-null  object
#  6   adjectives_jd         1193700 non-null  object
#  7   adverbs_jd            1193700 non-null  object
#  8   primary_skills_cr     1193700 non-null  object
#  9   secondary_skills_cr   1193700 non-null  object
#  10  adjectives_cr         1193700 non-null  object
#  11  adverbs_cr            1193700 non-null  object
#  12  adjectives_weight_cr  1193700 non-null  int64
# dtypes: int64(1), object(12)
# memory usage: 118.4+ MB

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

jd_ids = ['JOB_0', 'JOB_1']
results = []

TARGET = 10          # số cột muốn vẽ

for jd_id in jd_ids:
    subset = df_pairs.query("jd_id == @jd_id and primary_sim > 0") \
                           [['cr_id', 'primary_sim']] \
                           .sort_values('primary_sim')

    if len(subset) < TARGET:
        print(f"JD {jd_id} chỉ có {len(subset)} CR >0; bỏ qua.")
        continue

    # Chọn 10 chỉ số cách đều (linspace) trong range 0..len-1
    idx = np.linspace(0, len(subset)-1, TARGET, dtype=int)
    picked = subset.iloc[idx]

    # Nếu trùng primary_sim ⇒ loại trùng và bổ sung CR kế tiếp
    picked = picked.drop_duplicates('primary_sim')
    cursor  = 0
    while len(picked) < TARGET and cursor < len(subset):
        cand = subset.iloc[cursor]
        if cand['primary_sim'] not in picked['primary_sim'].values:
            picked = pd.concat([picked, cand.to_frame().T])
        cursor += 1

    picked['jd_id'] = jd_id
    results.append(picked)

# Gộp
df_plot = pd.concat(results, ignore_index=True)

# ─────── Vẽ ───────
colors = plt.cm.tab10.colors               # 10 màu khác nhau
for jd_id, grp in df_plot.groupby('jd_id'):
    plt.figure(figsize=(12, 5))
    plt.bar(grp['cr_id'], grp['primary_sim'], color=colors[:len(grp)])
    plt.xticks(rotation=45, ha='right')
    plt.ylabel('Jaccard Similarity')
    plt.title(f'JD {jd_id} — Top 10 non‑zero primary_sim (evenly spaced)')
    for i, v in enumerate(grp['primary_sim']):
        plt.text(i, v + 0.01, f"{v:.2f}", ha='center')
    plt.ylim(0, grp['primary_sim'].max()*1.15)
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\scope.py:231, in Scope.resolve(self, key, is_local)
#     230 if self.has_resolvers:
# --> 231     return self.resolvers[key]
#     233 # if we're here that means that we have no locals and we also have
#     234 # no resolvers
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\collections\__init__.py:986, in ChainMap.__getitem__(self, key)
#     985         pass
# --> 986 return self.__missing__(key)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\collections\__init__.py:978, in ChainMap.__missing__(self, key)
#     977 def __missing__(self, key):
# --> 978     raise KeyError(key)
#
# KeyError: 'primary_sim'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\scope.py:242, in Scope.resolve(self, key, is_local)
#     238 try:
#     239     # last ditch effort we look in temporaries
#     240     # these are created when parsing indexing expressions
#     241     # e.g., df[df > 0]
# --> 242     return self.temps[key]
#     243 except KeyError as err:
#
# KeyError: 'primary_sim'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# Cell In[32], line 11
#       8 TARGET = 10          # số cột muốn vẽ
#      10 for jd_id in jd_ids:
# ---> 11     subset = df_pairs.query("jd_id == @jd_id and primary_sim > 0") \
#      12                            [['cr_id', 'primary_sim']] \
#      13                            .sort_values('primary_sim')
#      15     if len(subset) < TARGET:
#      16         print(f"JD {jd_id} chỉ có {len(subset)} CR >0; bỏ qua.")
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4828, in DataFrame.query(self, expr, inplace, **kwargs)
#    4826 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4827 kwargs["target"] = None
# -> 4828 res = self.eval(expr, **kwargs)
#    4830 try:
#    4831     result = self.loc[res]
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4951     kwargs["target"] = self
#    4952 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4954 return _eval(expr, inplace=inplace, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\eval.py:339, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     330 # get our (possibly passed-in) scope
#     331 env = ensure_scope(
#     332     level + 1,
#     333     global_dict=global_dict,
#    (...)
#     336     target=target,
#     337 )
# --> 339 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     341 if engine == "numexpr" and (
#     342     (
#     343         is_extension_array_dtype(parsed_expr.terms.return_type)
#    (...)
#     350     )
#     351 ):
#     352     warnings.warn(
#     353         "Engine has switched to 'python' because numexpr does not support "
#     354         "extension array dtypes. Please set your engine to python manually.",
#     355         RuntimeWarning,
#     356         stacklevel=find_stack_level(),
#     357     )
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:419, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     417     raise SyntaxError("only a single expression is allowed")
#     418 expr = node.body[0]
# --> 419 return self.visit(expr, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:422, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     421 def visit_Expr(self, node, **kwargs):
# --> 422     return self.visit(node.value, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:746, in BaseExprVisitor.visit_BoolOp(self, node, **kwargs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#     745 operands = node.values
# --> 746 return reduce(visitor, operands)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:740, in BaseExprVisitor.visit_BoolOp.<locals>.visitor(x, y)
#     738 def visitor(x, y):
#     739     lhs = self._try_visit_binop(x)
# --> 740     rhs = self._try_visit_binop(y)
#     742     op, op_class, lhs, rhs = self._maybe_transform_eq_ne(node, lhs, rhs)
#     743     return self._maybe_evaluate_binop(op, node.op, lhs, rhs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:735, in BaseExprVisitor._try_visit_binop(self, bop)
#     733 if isinstance(bop, (Op, Term)):
#     734     return bop
# --> 735 return self.visit(bop)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:535, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     534 def visit_BinOp(self, node, **kwargs):
# --> 535     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     536     left, right = self._maybe_downcast_constants(left, right)
#     537     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:453, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     451 def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     452     if left is None:
# --> 453         left = self.visit(node.left, side="left")
#     454     if right is None:
#     455         right = self.visit(node.right, side="right")
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:413, in BaseExprVisitor.visit(self, node, **kwargs)
#     411 method = f"visit_{type(node).__name__}"
#     412 visitor = getattr(self, method)
# --> 413 return visitor(node, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expr.py:545, in BaseExprVisitor.visit_Name(self, node, **kwargs)
#     544 def visit_Name(self, node, **kwargs) -> Term:
# --> 545     return self.term_type(node.id, self.env, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\ops.py:91, in Term.__init__(self, name, env, side, encoding)
#      89 tname = str(name)
#      90 self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 91 self._value = self._resolve_name()
#      92 self.encoding = encoding
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\ops.py:115, in Term._resolve_name(self)
#     110 if local_name in self.env.scope and isinstance(
#     111     self.env.scope[local_name], type
#     112 ):
#     113     is_local = False
# --> 115 res = self.env.resolve(local_name, is_local=is_local)
#     116 self.update(res)
#     118 if hasattr(res, "ndim") and res.ndim > 2:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\scope.py:244, in Scope.resolve(self, key, is_local)
#     242     return self.temps[key]
#     243 except KeyError as err:
# --> 244     raise UndefinedVariableError(key, is_local) from err
#
# UndefinedVariableError: name 'primary_sim' is not defined
